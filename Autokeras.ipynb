# %%
pip install tensorflow==2.10.0 autokeras
# Out:
# Requirement already satisfied: tensorflow==2.10.0 in e:\automodelizer\.venv\lib\site-packages (2.10.0)
# Requirement already satisfied: autokeras in e:\automodelizer\.venv\lib\site-packages (1.1.0)
# Requirement already satisfied: absl-py>=1.0.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (24.3.7)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (3.10.0)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (16.0.6)
# Requirement already satisfied: numpy>=1.20 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (1.24.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (3.3.0)
# Requirement already satisfied: packaging in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (24.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (3.19.6)
# Requirement already satisfied: setuptools in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (41.2.0)
# Requirement already satisfied: six>=1.12.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (4.10.0)
# Requirement already satisfied: wrapt>=1.11.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (1.62.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: keras<2.11,>=2.10.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow==2.10.0) (2.10.0)
# Requirement already satisfied: keras-tuner>=1.1.0 in e:\automodelizer\.venv\lib\site-packages (from autokeras) (1.4.7)
# Requirement already satisfied: keras-nlp>=0.4.0 in e:\automodelizer\.venv\lib\site-packages (from autokeras) (0.6.1)
# Requirement already satisfied: pandas in e:\automodelizer\.venv\lib\site-packages (from autokeras) (2.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in e:\automodelizer\.venv\lib\site-packages (from astunparse>=1.6.0->tensorflow==2.10.0) (0.43.0)
# Requirement already satisfied: keras-core in e:\automodelizer\.venv\lib\site-packages (from keras-nlp>=0.4.0->autokeras) (0.1.5)
# Requirement already satisfied: regex in e:\automodelizer\.venv\lib\site-packages (from keras-nlp>=0.4.0->autokeras) (2023.12.25)
# Requirement already satisfied: rich in e:\automodelizer\.venv\lib\site-packages (from keras-nlp>=0.4.0->autokeras) (13.7.1)
# Requirement already satisfied: tensorflow-text in e:\automodelizer\.venv\lib\site-packages (from keras-nlp>=0.4.0->autokeras) (2.10.0)
# Requirement already satisfied: requests in e:\automodelizer\.venv\lib\site-packages (from keras-tuner>=1.1.0->autokeras) (2.31.0)
# Requirement already satisfied: kt-legacy in e:\automodelizer\.venv\lib\site-packages (from keras-tuner>=1.1.0->autokeras) (1.0.5)
# Requirement already satisfied: google-auth<3,>=1.6.3 in e:\automodelizer\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.28.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in e:\automodelizer\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in e:\automodelizer\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.5.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in e:\automodelizer\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in e:\automodelizer\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.8.1)
# Requirement already satisfied: werkzeug>=1.0.1 in e:\automodelizer\.venv\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in e:\automodelizer\.venv\lib\site-packages (from pandas->autokeras) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in e:\automodelizer\.venv\lib\site-packages (from pandas->autokeras) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in e:\automodelizer\.venv\lib\site-packages (from pandas->autokeras) (2024.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in e:\automodelizer\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (5.3.3)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in e:\automodelizer\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in e:\automodelizer\.venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in e:\automodelizer\.venv\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (1.4.0)
# Requirement already satisfied: importlib-metadata>=4.4 in e:\automodelizer\.venv\lib\site-packages (from markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (7.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\automodelizer\.venv\lib\site-packages (from requests->keras-tuner>=1.1.0->autokeras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\automodelizer\.venv\lib\site-packages (from requests->keras-tuner>=1.1.0->autokeras) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\automodelizer\.venv\lib\site-packages (from requests->keras-tuner>=1.1.0->autokeras) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in e:\automodelizer\.venv\lib\site-packages (from requests->keras-tuner>=1.1.0->autokeras) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in e:\automodelizer\.venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (2.1.5)
# Requirement already satisfied: namex in e:\automodelizer\.venv\lib\site-packages (from keras-core->keras-nlp>=0.4.0->autokeras) (0.0.7)
# Requirement already satisfied: dm-tree in e:\automodelizer\.venv\lib\site-packages (from keras-core->keras-nlp>=0.4.0->autokeras) (0.1.8)
# Requirement already satisfied: markdown-it-py>=2.2.0 in e:\automodelizer\.venv\lib\site-packages (from rich->keras-nlp>=0.4.0->autokeras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in e:\automodelizer\.venv\lib\site-packages (from rich->keras-nlp>=0.4.0->autokeras) (2.17.2)
# Requirement already satisfied: tensorflow-hub>=0.8.0 in e:\automodelizer\.venv\lib\site-packages (from tensorflow-text->keras-nlp>=0.4.0->autokeras) (0.16.1)
# Requirement already satisfied: zipp>=0.5 in e:\automodelizer\.venv\lib\site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.18.0)
# Requirement already satisfied: mdurl~=0.1 in e:\automodelizer\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras-nlp>=0.4.0->autokeras) (0.1.2)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in e:\automodelizer\.venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in e:\automodelizer\.venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow==2.10.0) (3.2.2)
# Requirement already satisfied: tf-keras>=2.14.1 in e:\automodelizer\.venv\lib\site-packages (from tensorflow-hub>=0.8.0->tensorflow-text->keras-nlp>=0.4.0->autokeras) (2.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# Lets see if CUDA is available
import tensorflow as tf

if tf.test.is_built_with_cuda():
    print("TensorFlow was built with CUDA")
else:
    print("TensorFlow was not built with CUDA")

print("GPUs available: ", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow was built with CUDA
# GPUs available:  [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import numpy as np
from tensorflow.keras.datasets import cifar100  # Cambio de MNIST a CIFAR-100
from tensorflow.keras.callbacks import EarlyStopping

import autokeras as ak

# Cargar el conjunto de datos CIFAR-100
(x_train, y_train), (x_test, y_test) = cifar100.load_data()

# Preprocesamiento de los datos
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# No necesitas cambiar la forma de x_train y x_test ya que ya están en la forma correcta para CIFAR-100 (32, 32, 3)

# Definir el modelo de clasificador de imágenes
clf = ak.ImageClassifier(overwrite=True, max_trials=10)  # max_trials define el número de modelos diferentes a probar

# Entrenar el modelo
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Entrenar el modelo con el callback de detención temprana
clf.fit(
    x_train, 
    y_train, 
    epochs=20,  # Ajusta según necesites
    validation_split=0.2,  # Usar un porcentaje de los datos para validación (ajusta según necesites)
    callbacks=[early_stopping]  # Pasar el callback de detención temprana
)
# Evaluar el modelo
evaluation = clf.evaluate(x_test, y_test)

# Obtener el modelo de Keras subyacente para su uso posterior
model = clf.export_model()
model.summary()

print("Evaluación del modelo en el conjunto de prueba:", evaluation)
# Out:
# Trial 1 Complete [00h 01m 01s]
# val_loss: 2.6218221187591553
#
# Best val_loss So Far: 2.6218221187591553
# Total elapsed time: 00h 01m 01s
#
# Search: Running Trial #2
#
# Value             |Best Value So Far |Hyperparameter
# resnet            |vanilla           |image_block_1/block_type
# True              |True              |image_block_1/normalize
# True              |False             |image_block_1/augment
# True              |None              |image_block_1/image_augmentation_1/horizontal_flip
# True              |None              |image_block_1/image_augmentation_1/vertical_flip
# 0                 |None              |image_block_1/image_augmentation_1/contrast_factor
# 0                 |None              |image_block_1/image_augmentation_1/rotation_factor
# 0.1               |None              |image_block_1/image_augmentation_1/translation_factor
# 0                 |None              |image_block_1/image_augmentation_1/zoom_factor
# False             |None              |image_block_1/res_net_block_1/pretrained
# resnet50          |None              |image_block_1/res_net_block_1/version
# True              |None              |image_block_1/res_net_block_1/imagenet_size
# global_avg        |flatten           |classification_head_1/spatial_reduction_1/reduction_type
# 0                 |0.5               |classification_head_1/dropout
# adam              |adam              |optimizer
# 0.001             |0.001             |learning_rate
#
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# Epoch 1/20
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting RngReadAndSkip cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting Bitcast cause there is no registered converter for this op.
# WARNING:tensorflow:Using a while_loop for converting StatelessRandomUniformV2 cause there is no registered converter for this op.
# 1167/1251 [==========================>...] - ETA: 40s - loss: 4.2467 - accuracy: 0.0636
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 23
#      20 early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
#      22 # Entrenar el modelo con el callback de detención temprana
# ---> 23 clf.fit(
#      24     x_train,
#      25     y_train,
#      26     epochs=20,  # Ajusta según necesites
#      27     validation_split=0.2,  # Usar un porcentaje de los datos para validación (ajusta según necesites)
#      28     callbacks=[early_stopping]  # Pasar el callback de detención temprana
#      29 )
#      30 # Evaluar el modelo
#      31 evaluation = clf.evaluate(x_test, y_test)
#
# File e:\AutoModelizer\.venv\lib\site-packages\autokeras\tasks\image.py:165, in ImageClassifier.fit(self, x, y, epochs, callbacks, validation_split, validation_data, **kwargs)
#     108 def fit(
#     109     self,
#     110     x: Optional[types.DatasetType] = None,
#    (...)
#     118     **kwargs
#     119 ):
#     120     """Search for the best model and hyperparameters for the AutoModel.
#     121
#     122     It will search for the best model based on the performances on
#    (...)
#     163             validation loss values and validation metrics values (if applicable).
#     164     """
# --> 165     history = super().fit(
#     166         x=x,
#     167         y=y,
#     168         epochs=epochs,
#     169         callbacks=callbacks,
#     170         validation_split=validation_split,
#     171         validation_data=validation_data,
#     172         **kwargs
#     173     )
#     174     return history
#
# File e:\AutoModelizer\.venv\lib\site-packages\autokeras\auto_model.py:292, in AutoModel.fit(self, x, y, batch_size, epochs, callbacks, validation_split, validation_data, verbose, **kwargs)
#     287 if validation_data is None and validation_split:
#     288     dataset, validation_data = data_utils.split_dataset(
#     289         dataset, validation_split
#     290     )
# --> 292 history = self.tuner.search(
#     293     x=dataset,
#     294     epochs=epochs,
#     295     callbacks=callbacks,
#     296     validation_data=validation_data,
#     297     validation_split=validation_split,
#     298     verbose=verbose,
#     299     **kwargs
#     300 )
#     302 return history
#
# File e:\AutoModelizer\.venv\lib\site-packages\autokeras\engine\tuner.py:193, in AutoTuner.search(self, epochs, callbacks, validation_split, verbose, **fit_kwargs)
#     191 self._try_build(hp)
#     192 self.oracle.update_space(hp)
# --> 193 super().search(
#     194     epochs=epochs, callbacks=new_callbacks, verbose=verbose, **fit_kwargs
#     195 )
#     197 # Train the best model use validation data.
#     198 # Train the best model with enough number of epochs.
#     199 if validation_split > 0 or early_stopping_inserted:
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras_tuner\src\engine\base_tuner.py:234, in BaseTuner.search(self, *fit_args, **fit_kwargs)
#     231         continue
#     233     self.on_trial_begin(trial)
# --> 234     self._try_run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     235     self.on_trial_end(trial)
#     236 self.on_search_end()
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras_tuner\src\engine\base_tuner.py:274, in BaseTuner._try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     272 def _try_run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
#     273     try:
# --> 274         self._run_and_update_trial(trial, *fit_args, **fit_kwargs)
#     275         trial.status = trial_module.TrialStatus.COMPLETED
#     276         return
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras_tuner\src\engine\base_tuner.py:239, in BaseTuner._run_and_update_trial(self, trial, *fit_args, **fit_kwargs)
#     238 def _run_and_update_trial(self, trial, *fit_args, **fit_kwargs):
# --> 239     results = self.run_trial(trial, *fit_args, **fit_kwargs)
#     240     if self.oracle.get_trial(trial.trial_id).metrics.exists(
#     241         self.oracle.objective.name
#     242     ):
#     243         # The oracle is updated by calling `self.oracle.update_trial()` in
#     244         # `Tuner.run_trial()`. For backward compatibility, we support this
#     245         # use case. No further action needed in this case.
#     246         warnings.warn(
#     247             "The use case of calling "
#     248             "`self.oracle.update_trial(trial_id, metrics)` "
#    (...)
#     254             stacklevel=2,
#     255         )
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras_tuner\src\engine\tuner.py:314, in Tuner.run_trial(self, trial, *args, **kwargs)
#     312     callbacks.append(model_checkpoint)
#     313     copied_kwargs["callbacks"] = callbacks
# --> 314     obj_value = self._build_and_fit_model(trial, *args, **copied_kwargs)
#     316     histories.append(obj_value)
#     317 return histories
#
# File e:\AutoModelizer\.venv\lib\site-packages\autokeras\engine\tuner.py:101, in AutoTuner._build_and_fit_model(self, trial, *args, **kwargs)
#      97 pipeline.save(self._pipeline_path(trial.trial_id))
#      99 self.adapt(model, kwargs["x"])
# --> 101 _, history = utils.fit_with_adaptive_batch_size(
#     102     model, self.hypermodel.batch_size, **kwargs
#     103 )
#     104 return history
#
# File e:\AutoModelizer\.venv\lib\site-packages\autokeras\utils\utils.py:88, in fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs)
#      87 def fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs):
# ---> 88     history = run_with_adaptive_batch_size(
#      89         batch_size, lambda **kwargs: model.fit(**kwargs), **fit_kwargs
#      90     )
#      91     return model, history
#
# File e:\AutoModelizer\.venv\lib\site-packages\autokeras\utils\utils.py:101, in run_with_adaptive_batch_size(batch_size, func, **fit_kwargs)
#      99 while batch_size > 0:
#     100     try:
# --> 101         history = func(x=x, validation_data=validation_data, **fit_kwargs)
#     102         break
#     103     except tf.errors.ResourceExhaustedError as e:
#
# File e:\AutoModelizer\.venv\lib\site-packages\autokeras\utils\utils.py:89, in fit_with_adaptive_batch_size.<locals>.<lambda>(**kwargs)
#      87 def fit_with_adaptive_batch_size(model, batch_size, **fit_kwargs):
#      88     history = run_with_adaptive_batch_size(
# ---> 89         batch_size, lambda **kwargs: model.fit(**kwargs), **fit_kwargs
#      90     )
#      91     return model, history
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras\engine\training.py:1570, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1568 logs = tmp_logs
#    1569 end_step = step + data_handler.step_increment
# -> 1570 callbacks.on_train_batch_end(end_step, logs)
#    1571 if self.stop_training:
#    1572     break
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras\callbacks.py:470, in CallbackList.on_train_batch_end(self, batch, logs)
#     463 """Calls the `on_train_batch_end` methods of its callbacks.
#     464
#     465 Args:
#     466     batch: Integer, index of batch within the current epoch.
#     467     logs: Dict. Aggregated metric results up until this batch.
#     468 """
#     469 if self._should_call_train_batch_hooks:
# --> 470     self._call_batch_hook(ModeKeys.TRAIN, "end", batch, logs=logs)
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras\callbacks.py:317, in CallbackList._call_batch_hook(self, mode, hook, batch, logs)
#     315     self._call_batch_begin_hook(mode, batch, logs)
#     316 elif hook == "end":
# --> 317     self._call_batch_end_hook(mode, batch, logs)
#     318 else:
#     319     raise ValueError(
#     320         f"Unrecognized hook: {hook}. "
#     321         'Expected values are ["begin", "end"]'
#     322     )
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras\callbacks.py:340, in CallbackList._call_batch_end_hook(self, mode, batch, logs)
#     337     batch_time = time.time() - self._batch_start_time
#     338     self._batch_times.append(batch_time)
# --> 340 self._call_batch_hook_helper(hook_name, batch, logs)
#     342 if len(self._batch_times) >= self._num_batches_for_timing_check:
#     343     end_hook_name = hook_name
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras\callbacks.py:385, in CallbackList._call_batch_hook_helper(self, hook_name, batch, logs)
#     382 if self._check_timing:
#     383     start_time = time.time()
# --> 385 logs = self._process_logs(logs, is_batch_hook=True)
#     386 for callback in self.callbacks:
#     387     hook = getattr(callback, hook_name)
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras\callbacks.py:292, in CallbackList._process_logs(self, logs, is_batch_hook)
#     290 if is_batch_hook and self._batch_hooks_support_tf_logs:
#     291     return logs
# --> 292 return tf_utils.sync_to_numpy_or_python_type(logs)
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras\utils\tf_utils.py:635, in sync_to_numpy_or_python_type(tensors)
#     632         return t
#     633     return t.item() if np.ndim(t) == 0 else t
# --> 635 return tf.nest.map_structure(_to_single_numpy_or_python_type, tensors)
#
# File e:\AutoModelizer\.venv\lib\site-packages\tensorflow\python\util\nest.py:917, in map_structure(func, *structure, **kwargs)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File e:\AutoModelizer\.venv\lib\site-packages\tensorflow\python\util\nest.py:917, in <listcomp>(.0)
#     913 flat_structure = (flatten(s, expand_composites) for s in structure)
#     914 entries = zip(*flat_structure)
#     916 return pack_sequence_as(
# --> 917     structure[0], [func(*x) for x in entries],
#     918     expand_composites=expand_composites)
#
# File e:\AutoModelizer\.venv\lib\site-packages\keras\utils\tf_utils.py:628, in sync_to_numpy_or_python_type.<locals>._to_single_numpy_or_python_type(t)
#     625 def _to_single_numpy_or_python_type(t):
#     626     # Don't turn ragged or sparse tensors to NumPy.
#     627     if isinstance(t, tf.Tensor):
# --> 628         t = t.numpy()
#     629     # Strings, ragged and sparse tensors don't have .item(). Return them
#     630     # as-is.
#     631     if not isinstance(t, (np.ndarray, np.generic)):
#
# File e:\AutoModelizer\.venv\lib\site-packages\tensorflow\python\framework\ops.py:1157, in _EagerTensorBase.numpy(self)
#    1134 """Copy of the contents of this Tensor into a NumPy array or scalar.
#    1135
#    1136 Unlike NumPy arrays, Tensors are immutable, so this method has to copy
#    (...)
#    1154     NumPy dtype.
#    1155 """
#    1156 # TODO(slebedev): Consider avoiding a copy for non-CPU or remote tensors.
# -> 1157 maybe_arr = self._numpy()  # pylint: disable=protected-access
#    1158 return maybe_arr.copy() if isinstance(maybe_arr, np.ndarray) else maybe_arr
#
# File e:\AutoModelizer\.venv\lib\site-packages\tensorflow\python\framework\ops.py:1123, in _EagerTensorBase._numpy(self)
#    1121 def _numpy(self):
#    1122   try:
# -> 1123     return self._numpy_internal()
#    1124   except core._NotOkStatusException as e:  # pylint: disable=protected-access
#    1125     raise core._status_to_exception(e) from None
#
# KeyboardInterrupt:
